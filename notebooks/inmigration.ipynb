# %%
import os
from os.path import join, dirname
import sys

SOURCE_CODE_PARENT = join(
    dirname(os.getcwd()),
    'src'
)

DATA_PARENT = join(
    dirname(os.getcwd()),
    'data'
)

sys.path.append(SOURCE_CODE_PARENT)

# %%
import pandas as pd

csv_name = 'immigration_data.csv'
df = pd.read_csv(
    join(DATA_PARENT, csv_name)
)
df.head()
# Out:
#                     id                                               text  \
# 0  1674564893696045065  @GoldingBF Giorgia is halting the migrant boat...
# 1  1674559792147251200  @andyw8924 @Patriot6112 He should take a good ...
# 2  1674559366295429120  @hennessy_ro @kelehan_kevin3 It's a fact that ...
# 3  1674557580473950210  @FlowersEnglish And not a single question abou...
# 4  1674556825914466305  @gavreilly Why don't you report on something t...
#
#                   created_at lang   source           name       screen_name  \
# 0  2023-06-29T23:45:57+00:00   en  twitter  John Mitchell  @JohnMit15280981
# 1  2023-06-29T23:25:40+00:00   en  twitter  Maureen Dalby     @MaureenDalby
# 2  2023-06-29T23:23:59+00:00   en  twitter  🇮🇪Taxi Dave🇮🇪   @DublinTaxiDave
# 3  2023-06-29T23:16:53+00:00   en  twitter  Maureen Dalby     @MaureenDalby
# 4  2023-06-29T23:13:53+00:00   en  twitter      karlosdub        @Karlosdub
#
#                                                  bio  \
# 0  Computing with Artificial Intelligence Machine...
# 1  Anglo-Irish. Love animals and living in rural ...
# 2  🇮🇪🇮🇪🇮🇪Proud co-founder of "Irish Taxi Drivers ...
# 3  Anglo-Irish. Love animals and living in rural ...
# 4                                                NaN
#
#                us_created_at  followers_count  friends_count  statuses_count  \
# 0  2021-01-02T13:44:00+00:00               47             93            3950
# 1  2018-10-12T08:11:27+00:00            30174          25651           79003
# 2  2022-12-26T18:35:33+00:00             2526           3011            8323
# 3  2018-10-12T08:11:27+00:00            30174          25651           79003
# 4  2009-11-07T17:32:44+00:00              142            201            7063
#
#    favourites_count  country country_code locality    region   sub_region  \
# 0              1324  Ireland           IE      NaN       NaN          NaN
# 1            299967  Ireland           IE      NaN       NaN          NaN
# 2             11866  Ireland           IE   Dublin  Leinster  Dublin City
# 3            299967  Ireland           IE      NaN       NaN          NaN
# 4             18676  Ireland           IE   Dublin  Leinster  Dublin City
#
#           coordinates
# 0          53.0, -8.0
# 1          53.0, -8.0
# 2  53.33306, -6.24889
# 3          53.0, -8.0
# 4  53.33306, -6.24889

# %%
df['date'] = df['created_at'].apply(lambda x: x[:10])
df.head()
# Out:
#                     id                                               text  \
# 0  1674564893696045065  @GoldingBF Giorgia is halting the migrant boat...
# 1  1674559792147251200  @andyw8924 @Patriot6112 He should take a good ...
# 2  1674559366295429120  @hennessy_ro @kelehan_kevin3 It's a fact that ...
# 3  1674557580473950210  @FlowersEnglish And not a single question abou...
# 4  1674556825914466305  @gavreilly Why don't you report on something t...
#
#                   created_at lang   source           name       screen_name  \
# 0  2023-06-29T23:45:57+00:00   en  twitter  John Mitchell  @JohnMit15280981
# 1  2023-06-29T23:25:40+00:00   en  twitter  Maureen Dalby     @MaureenDalby
# 2  2023-06-29T23:23:59+00:00   en  twitter  🇮🇪Taxi Dave🇮🇪   @DublinTaxiDave
# 3  2023-06-29T23:16:53+00:00   en  twitter  Maureen Dalby     @MaureenDalby
# 4  2023-06-29T23:13:53+00:00   en  twitter      karlosdub        @Karlosdub
#
#                                                  bio  \
# 0  Computing with Artificial Intelligence Machine...
# 1  Anglo-Irish. Love animals and living in rural ...
# 2  🇮🇪🇮🇪🇮🇪Proud co-founder of "Irish Taxi Drivers ...
# 3  Anglo-Irish. Love animals and living in rural ...
# 4                                                NaN
#
#                us_created_at  followers_count  friends_count  statuses_count  \
# 0  2021-01-02T13:44:00+00:00               47             93            3950
# 1  2018-10-12T08:11:27+00:00            30174          25651           79003
# 2  2022-12-26T18:35:33+00:00             2526           3011            8323
# 3  2018-10-12T08:11:27+00:00            30174          25651           79003
# 4  2009-11-07T17:32:44+00:00              142            201            7063
#
#    favourites_count  country country_code locality    region   sub_region  \
# 0              1324  Ireland           IE      NaN       NaN          NaN
# 1            299967  Ireland           IE      NaN       NaN          NaN
# 2             11866  Ireland           IE   Dublin  Leinster  Dublin City
# 3            299967  Ireland           IE      NaN       NaN          NaN
# 4             18676  Ireland           IE   Dublin  Leinster  Dublin City
#
#           coordinates        date
# 0          53.0, -8.0  2023-06-29
# 1          53.0, -8.0  2023-06-29
# 2  53.33306, -6.24889  2023-06-29
# 3          53.0, -8.0  2023-06-29
# 4  53.33306, -6.24889  2023-06-29

# %%
from alerts import preprocess

freq_per_day_df = preprocess.data2timeSeries(df)
freq_per_day_df.head()
# Out:
#              id  text  created_at  lang  source  name  screen_name  bio  \
# date
# 2023-05-01  104   104         104   104     104   104          104   92
# 2023-05-02  140   140         140   140     140   140          140  132
# 2023-05-03  188   188         188   188     188   188          188  167
# 2023-05-04  168   168         168   168     168   168          168  155
# 2023-05-05  123   123         123   123     123   123          123  111
#
#             us_created_at  followers_count  friends_count  statuses_count  \
# date
# 2023-05-01            104              104            104             104
# 2023-05-02            140              140            140             140
# 2023-05-03            188              188            188             188
# 2023-05-04            168              168            168             168
# 2023-05-05            123              123            123             123
#
#             favourites_count  country  country_code  locality  region  \
# date
# 2023-05-01               104      100           100        36      36
# 2023-05-02               140      139           139        74      74
# 2023-05-03               188      185           185        80      81
# 2023-05-04               168      167           167        76      77
# 2023-05-05               123      121           121        58      60
#
#             sub_region  coordinates
# date
# 2023-05-01          34          100
# 2023-05-02          73          139
# 2023-05-03          79          185
# 2023-05-04          76          167
# 2023-05-05          56          121

# %%
df.index.values[:4], df.text.values[:4]
# Out:
# (array([0, 1, 2, 3]),
#  array(["@GoldingBF Giorgia is halting the migrant boats. Stemming the tide. Give her time to start the deportations. She has to prove Fratelli d'Italia can govern Italy. She's doing well, laying the ground work.",
#         '@andyw8924 @Patriot6112 He should take a good look at the ongoing migrant riots in France...these are the people coming across in dinghies.',
#         '@hennessy_ro @kelehan_kevin3 It\'s a fact that the Indigenous Irish will be a  minority in their own country if Immigration isn\'t stopped.\n\nAre the Irish Times "racist" or "far-right" for highlighting the problem  ?\n\n#IrelandisFull https://t.co/qfhvrPkr17',
#         '@FlowersEnglish And not a single question about how the migrant gangs are rioting in France!'],
#        dtype=object))

# %%
from alerts.time_series import AnomalyTS

T = zip(freq_per_day_df.index.values, freq_per_day_df.text.values)
parameters = {
    'window': 5
}
ts = AnomalyTS(T, parameters)
ts.plot()

# %%
T = zip(freq_per_day_df.index.values, freq_per_day_df.text.values)
parameters = {
    'window': 5
}
ts = AnomalyTS(T, parameters)
T = ts.normalize_time_series()
parameters = {
    'window': 5
}
ts = AnomalyTS(T, parameters)
ts.plot()

# %%
import pandas as pd

T = zip(freq_per_day_df.index.values, freq_per_day_df.text.values)
parameters = {
    'window': 30
}
ts = AnomalyTS(T, parameters)

predictions = ts.prediction_interval()
pred_df = pd.DataFrame(predictions).tail(60)
pred_df.head(50)
# Out:
#         dates  values          lb          ub  flatten_values  flatten_lb  \
# 0  2023-05-01     104         NaN         NaN       10.198039         NaN
# 1  2023-05-02     140         NaN         NaN       11.832160         NaN
# 2  2023-05-03     188         NaN         NaN       13.711309         NaN
# 3  2023-05-04     168         NaN         NaN       12.961481         NaN
# 4  2023-05-05     123         NaN         NaN       11.090537         NaN
# 5  2023-05-06      90         NaN         NaN        9.486833         NaN
# 6  2023-05-07     134         NaN         NaN       11.575837         NaN
# 7  2023-05-08     229         NaN         NaN       15.132746         NaN
# 8  2023-05-09     265         NaN         NaN       16.278821         NaN
# 9  2023-05-10     255         NaN         NaN       15.968719         NaN
# 10 2023-05-11     249         NaN         NaN       15.779734         NaN
# 11 2023-05-12     389         NaN         NaN       19.723083         NaN
# 12 2023-05-13     776         NaN         NaN       27.856777         NaN
# 13 2023-05-14     444         NaN         NaN       21.071308         NaN
# 14 2023-05-15     497         NaN         NaN       22.293497         NaN
# 15 2023-05-16     701         NaN         NaN       26.476405         NaN
# 16 2023-05-17     863         NaN         NaN       29.376862         NaN
# 17 2023-05-18     754         NaN         NaN       27.459060         NaN
# 18 2023-05-19     713         NaN         NaN       26.702060         NaN
# 19 2023-05-20     434         NaN         NaN       20.832667         NaN
# 20 2023-05-21     479         NaN         NaN       21.886069         NaN
# 21 2023-05-22     394         NaN         NaN       19.849433         NaN
# 22 2023-05-23     446         NaN         NaN       21.118712         NaN
# 23 2023-05-24     414         NaN         NaN       20.346990         NaN
# 24 2023-05-25     442         NaN         NaN       21.023796         NaN
# 25 2023-05-26     394         NaN         NaN       19.849433         NaN
# 26 2023-05-27     767         NaN         NaN       27.694765         NaN
# 27 2023-05-28     482         NaN         NaN       21.954498         NaN
# 28 2023-05-29     375         NaN         NaN       19.364917         NaN
# 29 2023-05-30     352         NaN         NaN       18.761663         NaN
# 30 2023-05-31     247   47.783213  756.283453       15.716234   10.168665
# 31 2023-06-01     234   60.779178  752.820822       15.297059   10.700855
# 32 2023-06-02     273   69.246891  750.619775       16.522712   11.025914
# 33 2023-06-03     205   76.075272  749.458061       14.317821   11.250754
# 34 2023-06-04     212   79.510417  748.489583       14.560220   11.382153
# 35 2023-06-05     219   88.336250  745.597083       14.798649   11.756328
# 36 2023-06-06     218  101.910014  740.623319       14.764823   12.396989
# 37 2023-06-07     231  110.472840  737.660494       15.198684   12.761750
# 38 2023-06-08     483  110.648487  737.618180       21.977261   12.767850
# 39 2023-06-09     323  121.223694  741.576306       17.972201   13.030848
# 40 2023-06-10     251  126.272575  741.060758       15.842980   13.179478
# 41 2023-06-11     206  126.444463  741.022203       14.352700   13.185112
# 42 2023-06-12     251  113.440663  741.826004       15.842980   12.796420
# 43 2023-06-13     221  110.179363  710.087304       14.866069   12.669833
# 44 2023-06-14     206   97.947391  707.452609       14.352700   12.333316
# 45 2023-06-15     312   84.376320  701.623680       17.663522   11.961975
# 46 2023-06-16     396   85.021313  675.045354       19.899749   11.982907
# 47 2023-06-17     225  107.789448  621.143886       15.000000   12.391472
# 48 2023-06-18     212  115.709397  577.957270       14.560220   12.473351
# 49 2023-06-19     297  124.025615  536.241052       17.233688   12.560011
#
#     flatten_ub
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30   28.341882
# 31   28.177572
# 32   28.083506
# 33   28.046093
# 34   28.005116
# 35   27.862254
# 36   27.575714
# 37   27.423552
# 38   27.421848
# 39   27.538746
# 40   27.523681
# 41   27.522263
# 42   27.552930
# 43   26.878597
# 44   26.801431
# 45   26.643387
# 46   26.034929
# 47   24.994556
# 48   24.082073
# 49   23.185957

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(12, 5))


simplified_preds = pred_df[~pred_df['lb'].isna()]

plt.plot(
    simplified_preds['dates'],
    simplified_preds['values'],
    label='value'
)

plt.plot(
    simplified_preds['dates'],
    simplified_preds['lb'],
    label='lb'
)

plt.plot(
    simplified_preds['dates'],
    simplified_preds['ub'],
    label='ub'
)

plt.xlabel("Angle")
plt.ylabel("Magnitude")
plt.title("Time series")

plt.legend()


plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(12, 5))


simplified_preds = pred_df[~pred_df['lb'].isna()]

plt.plot(
    simplified_preds['dates'],
    simplified_preds['flatten_values'],
    label='value'
)

plt.plot(
    simplified_preds['dates'],
    simplified_preds['flatten_lb'],
    label='lb'
)

