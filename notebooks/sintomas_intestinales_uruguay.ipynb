# %%
import os
from os.path import join, dirname
import sys

SOURCE_CODE_PARENT = join(
    dirname(os.getcwd()),
    'src'
)

DATA_PARENT = join(
    dirname(os.getcwd()),
    'data'
)

sys.path.append(SOURCE_CODE_PARENT)

# %%
import pandas as pd

csv_name = 'Sintomas_intestinales_uruguay.csv'
df = pd.read_csv(
    join(DATA_PARENT, csv_name)
)
df.head()
# Out:
#                     id                                               text  \
# 0  1613402886142308353  Me acabé de despertar con anciedad, lo único q...
# 1  1613399780641611776  Puedo decir que ya recuerdo xq odio fumar cogo...
# 2  1613378042029539328  @soffi_avilaa q asco sofia, me dan nauseas lee...
# 3  1613377962828595202  @VanderolaJr Gracias. Si necesito vomitar lo e...
# 4  1613377512163131395  El destino elegido por los uruguayos: Florianó...
#
#                   created_at lang   source                       name  \
# 0  2023-01-12T05:09:58+00:00   es  twitter                         L✨
# 1  2023-01-12T04:57:37+00:00   es  twitter                   motomami
# 2  2023-01-12T03:31:14+00:00   es  twitter                  𝒇𝒍𝒐𝒓𝒆𝒏𝒄𝒊𝒂
# 3  2023-01-12T03:30:56+00:00   es  twitter  Ing. El Herrante (trucho)
# 4  2023-01-12T03:29:08+00:00   es  twitter                    EL PAÍS
#
#         screen_name                                                bio  \
# 0  @letiigonzalez17                                22 años ❄️ ♍️ virgo
# 1         @candus21                                     ig : ponny_21_
# 2   @flor_rosenberg                                 ig; floren_rosen07
# 3      @el_herrante  Uruguayo.\nDefensor Sporting en todos los depo...
# 4         @elpaisuy  Diario El País de Uruguay. http://elpais.uy/li...
#
#                us_created_at  followers_count  friends_count  statuses_count  \
# 0  2015-07-17T22:46:12+00:00              177            151           14140
# 1  2013-12-30T01:31:46+00:00              380            686           48696
# 2  2021-07-02T04:54:29+00:00               45             43            1313
# 3  2010-04-09T13:32:06+00:00             2241           2163           62087
# 4  2009-04-15T17:18:57+00:00           834127            669          541454
#
#    favourites_count  country country_code    locality       region sub_region  \
# 0              8818  Uruguay           UY         NaN          NaN        NaN
# 1             19649  Uruguay           UY  Montevideo   Montevideo        NaN
# 2             29637  Uruguay           UY         NaN  Cerro Largo        NaN
# 3            110565  Uruguay           UY         NaN          NaN        NaN
# 4              1959  Uruguay           UY  Montevideo   Montevideo        NaN
#
#             coordinates
# 0          -33.0, -56.0
# 1  -34.83346, -56.16735
# 2  -32.33333, -54.33333
# 3          -33.0, -56.0
# 4  -34.83346, -56.16735

# %%
df['date'] = df['created_at'].apply(lambda x: x[:10])
df.head()
# Out:
#                     id                                               text  \
# 0  1613402886142308353  Me acabé de despertar con anciedad, lo único q...
# 1  1613399780641611776  Puedo decir que ya recuerdo xq odio fumar cogo...
# 2  1613378042029539328  @soffi_avilaa q asco sofia, me dan nauseas lee...
# 3  1613377962828595202  @VanderolaJr Gracias. Si necesito vomitar lo e...
# 4  1613377512163131395  El destino elegido por los uruguayos: Florianó...
#
#                   created_at lang   source                       name  \
# 0  2023-01-12T05:09:58+00:00   es  twitter                         L✨
# 1  2023-01-12T04:57:37+00:00   es  twitter                   motomami
# 2  2023-01-12T03:31:14+00:00   es  twitter                  𝒇𝒍𝒐𝒓𝒆𝒏𝒄𝒊𝒂
# 3  2023-01-12T03:30:56+00:00   es  twitter  Ing. El Herrante (trucho)
# 4  2023-01-12T03:29:08+00:00   es  twitter                    EL PAÍS
#
#         screen_name                                                bio  \
# 0  @letiigonzalez17                                22 años ❄️ ♍️ virgo
# 1         @candus21                                     ig : ponny_21_
# 2   @flor_rosenberg                                 ig; floren_rosen07
# 3      @el_herrante  Uruguayo.\nDefensor Sporting en todos los depo...
# 4         @elpaisuy  Diario El País de Uruguay. http://elpais.uy/li...
#
#                us_created_at  followers_count  friends_count  statuses_count  \
# 0  2015-07-17T22:46:12+00:00              177            151           14140
# 1  2013-12-30T01:31:46+00:00              380            686           48696
# 2  2021-07-02T04:54:29+00:00               45             43            1313
# 3  2010-04-09T13:32:06+00:00             2241           2163           62087
# 4  2009-04-15T17:18:57+00:00           834127            669          541454
#
#    favourites_count  country country_code    locality       region sub_region  \
# 0              8818  Uruguay           UY         NaN          NaN        NaN
# 1             19649  Uruguay           UY  Montevideo   Montevideo        NaN
# 2             29637  Uruguay           UY         NaN  Cerro Largo        NaN
# 3            110565  Uruguay           UY         NaN          NaN        NaN
# 4              1959  Uruguay           UY  Montevideo   Montevideo        NaN
#
#             coordinates        date
# 0          -33.0, -56.0  2023-01-12
# 1  -34.83346, -56.16735  2023-01-12
# 2  -32.33333, -54.33333  2023-01-12
# 3          -33.0, -56.0  2023-01-12
# 4  -34.83346, -56.16735  2023-01-12

# %%
from alerts import preprocess

freq_per_day_df = preprocess.data2timeSeries(df)
freq_per_day_df.head()
# Out:
#             id  text  created_at  lang  source  name  screen_name  bio  \
# date
# 2023-01-01  36    36          36    36      36    36           36   33
# 2023-01-02  30    30          30    30      30    30           30   26
# 2023-01-03  29    29          29    29      29    29           29   22
# 2023-01-04  46    46          46    46      46    46           46   41
# 2023-01-05  57    57          57    57      57    57           57   42
#
#             us_created_at  followers_count  friends_count  statuses_count  \
# date
# 2023-01-01             36               36             36              36
# 2023-01-02             30               30             30              30
# 2023-01-03             29               29             29              29
# 2023-01-04             46               46             46              46
# 2023-01-05             57               57             57              57
#
#             favourites_count  country  country_code  locality  region  \
# date
# 2023-01-01                36       33            33        26      26
# 2023-01-02                30       27            27        19      20
# 2023-01-03                29       28            28        19      22
# 2023-01-04                46       39            39        28      30
# 2023-01-05                57       54            54        42      46
#
#             sub_region  coordinates
# date
# 2023-01-01           0           33
# 2023-01-02           0           27
# 2023-01-03           0           28
# 2023-01-04           0           39
# 2023-01-05           0           54

# %%
df.index.values[:4], df.text.values[:4]
# Out:
# (array([0, 1, 2, 3]),
#  array(['Me acabé de despertar con anciedad, lo único que tenia para comer era helado, el tema es que tenia gusto a “frezzer” y ahora solo tengo ganas de vomitar 😓😶😢',
#         'Puedo decir que ya recuerdo xq odio fumar cogo y encima estaba el mejor firme  pero bue ES Xq no si#Oporto el viaje odio vomitar',
#         '@soffi_avilaa q asco sofia, me dan nauseas leer tu tweet',
#         '@VanderolaJr Gracias. Si necesito vomitar lo escucho.'],
#        dtype=object))

# %%
from alerts.time_series import AnomalyTS

T = zip(freq_per_day_df.index.values, freq_per_day_df.text.values)
parameters = {
    'window': 30,
    'static_metric': 'mean',
    'transf': None
}
ts = AnomalyTS(T, parameters)
ts.plot(show_anomalies=True)

# %%
from alerts.time_series import AnomalyTS

T = zip(freq_per_day_df.index.values, freq_per_day_df.text.values)
parameters = {
    'window': 30,
    'static_metric': 'mean',
    'transf': 'sqrt'
}
ts = AnomalyTS(T, parameters)
ts.plot(show_anomalies=True)

# %%
from alerts.time_series import AnomalyTS

T = zip(freq_per_day_df.index.values, freq_per_day_df.text.values)
parameters = {
    'window': 30,
    'static_metric': 'median',
    'transf': None
}
ts = AnomalyTS(T, parameters)
ts.plot(show_anomalies=True)

# %%
from alerts.time_series import AnomalyTS

T = zip(freq_per_day_df.index.values, freq_per_day_df.text.values)
parameters = {
    'window': 30,
    'static_metric': 'median',
    'transf': 'sqrt'
}
ts = AnomalyTS(T, parameters)
ts.plot(show_anomalies=True)
